# %%
import pandas as pd 
import os
feature_name_dict = {'Sidewalk width': 'sidewalk_width',
                        'Pedestrian density': 'pedestrian_density',
                        'Density of street furniture (e.g. garbage, poles)': 'street_furniture_density',
                        'Sidewalk / Surface roughness': 'sidewalk_roughness',
                        'Surface condition': 'surface_condition',
                        'Wireless communication infrastructure (e.g. 5G, IoT, Wi-Fi)': 'communication_infrastructure',
                        'Slope gradient (i.e. elevation change)': 'slope_gradient',
                        'Proximity to charging stations': 'charging_station_proximity',
                        'Local attitudes towards robots': 'local_attitudes',
                        'Curb ramp availability': 'curb_ramp_availability',
                        'Weather conditions': 'weather_conditions',
                        'Crowd dynamics - purpose with which people navigate in the space': 'crowd_dynamics',
                        'Traffic management systems': 'traffic_management',
                        'Surveillance coverage (CCTV)': 'surveillance_coverage',
                        'Zoning laws and regulation': 'zoning_laws',
                        'Bike lane availability': 'bike_lane_availability',
                        'Street lighting': 'street_lighting',
                        'Existence of shade (e.g., trees)': 'shade_availability',
                        'GPS signal strength': 'gps_signal_strength',
                        'Pedestrian flow': 'pedestrian_flow',
                        'Bicycle traffic': 'bicycle_traffic',
                        'Vehicle traffic': 'vehicle_traffic',
                        'Existence of detailed digital maps of the area': 'digital_map_existence',
                        'Intersection safety': 'intersection_safety'}

# %%
all_weights = pd.read_csv("all_weights.csv", index_col=0)
industry_weights = pd.read_csv("industry_weights.csv", index_col=0)
academia_weights = pd.read_csv("academia_weights.csv", index_col=0)
trashbot_weights = pd.read_csv("trashbot_weights.csv", index_col=0)

# %%
# reverse the dictionary
feature_name_dict = {v: k for k, v in feature_name_dict.items()}
feature_name_dict
# Out:
# {'sidewalk_width': 'Sidewalk width',
#  'pedestrian_density': 'Pedestrian density',
#  'street_furniture_density': 'Density of street furniture (e.g. garbage, poles)',
#  'sidewalk_roughness': 'Sidewalk / Surface roughness',
#  'surface_condition': 'Surface condition',
#  'communication_infrastructure': 'Wireless communication infrastructure (e.g. 5G, IoT, Wi-Fi)',
#  'slope_gradient': 'Slope gradient (i.e. elevation change)',
#  'charging_station_proximity': 'Proximity to charging stations',
#  'local_attitudes': 'Local attitudes towards robots',
#  'curb_ramp_availability': 'Curb ramp availability',
#  'weather_conditions': 'Weather conditions',
#  'crowd_dynamics': 'Crowd dynamics - purpose with which people navigate in the space',
#  'traffic_management': 'Traffic management systems',
#  'surveillance_coverage': 'Surveillance coverage (CCTV)',
#  'zoning_laws': 'Zoning laws and regulation',
#  'bike_lane_availability': 'Bike lane availability',
#  'street_lighting': 'Street lighting',
#  'shade_availability': 'Existence of shade (e.g., trees)',
#  'gps_signal_strength': 'GPS signal strength',
#  'pedestrian_flow': 'Pedestrian flow',
#  'bicycle_traffic': 'Bicycle traffic',
#  'vehicle_traffic': 'Vehicle traffic',
#  'digital_map_existence': 'Existence of detailed digital maps of the area',
#  'intersection_safety': 'Intersection safety'}

# %%
all_weights.index = all_weights.index.map(feature_name_dict)
industry_weights.index = industry_weights.index.map(feature_name_dict)
academia_weights.index = academia_weights.index.map(feature_name_dict)
trashbot_weights.index = trashbot_weights.index.map(feature_name_dict)

# %%
# merge all the weights with one column for each 
all_weights = all_weights.rename(columns={'Weight': 'All'})
industry_weights = industry_weights.rename(columns={'Weight': 'Industry'})
academia_weights = academia_weights.rename(columns={'Weight': 'Academia'})
trashbot_weights = trashbot_weights.rename(columns={'Weight': 'Trashbot'})

# %%
# merge 
all_weights = all_weights.merge(industry_weights, left_index=True, right_index=True, how='outer')
all_weights = all_weights.merge(academia_weights, left_index=True, right_index=True, how='outer')
all_weights = all_weights.merge(trashbot_weights, left_index=True, right_index=True, how='outer')

# %%
# sort by 'All' 
all_weights = all_weights.sort_values(by='All', ascending=False)
all_weights
# Out:
#                                                          All  Industry  \
# Feature
# Pedestrian density                                  0.072944  0.054577
# Crowd dynamics - purpose with which people navi...  0.063126  0.066903
# Pedestrian flow                                     0.062957  0.027362
# Surface condition                                   0.057289  0.088080
# Intersection safety                                 0.057254  0.070165
# Density of street furniture (e.g. garbage, poles)   0.053924  0.072495
# Sidewalk width                                      0.053274  0.038608
# Weather conditions                                  0.051378  0.049333
# Wireless communication infrastructure (e.g. 5G,...  0.048969  0.061403
# Curb ramp availability                              0.048322  0.032841
# Sidewalk / Surface roughness                        0.041455  0.015622
# GPS signal strength                                 0.040063  0.030021
# Local attitudes towards robots                      0.039427  0.040719
# Existence of detailed digital maps of the area      0.038870  0.056822
# Traffic management systems                          0.038201  0.069074
# Vehicle traffic                                     0.037391  0.027062
# Slope gradient (i.e. elevation change)              0.037232  0.019583
# Zoning laws and regulation                          0.034909  0.015316
# Street lighting                                     0.026465  0.037820
# Bicycle traffic                                     0.024624  0.004679
# Proximity to charging stations                      0.021615  0.046147
# Bike lane availability                              0.019874  0.018392
# Surveillance coverage (CCTV)                        0.018822  0.056976
# Existence of shade (e.g., trees)                    0.011616 -0.000000
#
#                                                     Academia  Trashbot
# Feature
# Pedestrian density                                  0.072103  0.119692
# Crowd dynamics - purpose with which people navi...  0.069595  0.099848
# Pedestrian flow                                     0.068887       NaN
# Surface condition                                   0.053689  0.101684
# Intersection safety                                 0.058207       NaN
# Density of street furniture (e.g. garbage, poles)   0.056142  0.083682
# Sidewalk width                                      0.060283  0.083182
# Weather conditions                                  0.058861       NaN
# Wireless communication infrastructure (e.g. 5G,...  0.034756  0.068942
# Curb ramp availability                              0.052322  0.081910
# Sidewalk / Surface roughness                        0.038723  0.052740
# GPS signal strength                                 0.030790  0.059464
# Local attitudes towards robots                      0.041909       NaN
# Existence of detailed digital maps of the area      0.034065  0.060649
# Traffic management systems                          0.037969       NaN
# Vehicle traffic                                     0.038860       NaN
# Slope gradient (i.e. elevation change)              0.042055  0.062835
# Zoning laws and regulation                          0.035581       NaN
# Street lighting                                     0.021987       NaN
# Bicycle traffic                                     0.026930  0.035245
# Proximity to charging stations                      0.018071  0.032634
# Bike lane availability                              0.020819  0.026631
# Surveillance coverage (CCTV)                        0.016312  0.030862
# Existence of shade (e.g., trees)                    0.011084       NaN

# %%
# round to 3 decimals, take absolute value, and convert to string. then replace nan with '-'
all_weights = all_weights.applymap(lambda x: f"{abs(x):.3f}" if pd.notnull(x) else '-')
# Out:
# /tmp/ipykernel_1799228/4016278521.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   all_weights = all_weights.applymap(lambda x: f"{abs(x):.3f}" if pd.notnull(x) else '-')

# %%
all_weights
# Out:
#                                                       All Industry Academia  \
# Feature
# Pedestrian density                                  0.073    0.055    0.072
# Crowd dynamics - purpose with which people navi...  0.063    0.067    0.070
# Pedestrian flow                                     0.063    0.027    0.069
# Surface condition                                   0.057    0.088    0.054
# Intersection safety                                 0.057    0.070    0.058
# Density of street furniture (e.g. garbage, poles)   0.054    0.072    0.056
# Sidewalk width                                      0.053    0.039    0.060
# Weather conditions                                  0.051    0.049    0.059
# Wireless communication infrastructure (e.g. 5G,...  0.049    0.061    0.035
# Curb ramp availability                              0.048    0.033    0.052
# Sidewalk / Surface roughness                        0.041    0.016    0.039
# GPS signal strength                                 0.040    0.030    0.031
# Local attitudes towards robots                      0.039    0.041    0.042
# Existence of detailed digital maps of the area      0.039    0.057    0.034
# Traffic management systems                          0.038    0.069    0.038
# Vehicle traffic                                     0.037    0.027    0.039
# Slope gradient (i.e. elevation change)              0.037    0.020    0.042
# Zoning laws and regulation                          0.035    0.015    0.036
# Street lighting                                     0.026    0.038    0.022
# Bicycle traffic                                     0.025    0.005    0.027
# Proximity to charging stations                      0.022    0.046    0.018
# Bike lane availability                              0.020    0.018    0.021
# Surveillance coverage (CCTV)                        0.019    0.057    0.016
# Existence of shade (e.g., trees)                    0.012    0.000    0.011
#
#                                                    Trashbot
# Feature
# Pedestrian density                                    0.120
# Crowd dynamics - purpose with which people navi...    0.100
# Pedestrian flow                                           -
# Surface condition                                     0.102
# Intersection safety                                       -
# Density of street furniture (e.g. garbage, poles)     0.084
# Sidewalk width                                        0.083
# Weather conditions                                        -
# Wireless communication infrastructure (e.g. 5G,...    0.069
# Curb ramp availability                                0.082
# Sidewalk / Surface roughness                          0.053
# GPS signal strength                                   0.059
# Local attitudes towards robots                            -
# Existence of detailed digital maps of the area        0.061
# Traffic management systems                                -
# Vehicle traffic                                           -
# Slope gradient (i.e. elevation change)                0.063
# Zoning laws and regulation                                -
# Street lighting                                           -
# Bicycle traffic                                       0.035
# Proximity to charging stations                        0.033
# Bike lane availability                                0.027
# Surveillance coverage (CCTV)                          0.031
# Existence of shade (e.g., trees)                          -

# %%
# produce pretty latex table 
os.makedirs('../chi24_roving_whiteboards/tables', exist_ok=True)
all_weights.to_latex('../chi24_roving_whiteboards/tables/feature_weights.tex')
